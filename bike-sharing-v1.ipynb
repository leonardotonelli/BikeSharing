# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # EDA

# %%
df = pd.read_csv("/kaggle/input/bike-sharing-demand/train.csv")
count = df["count"]
temp = df["atemp"]
sns.scatterplot(x = count, y = temp, hue= df["workingday"])
# Out:
# <Axes: xlabel='count', ylabel='atemp'>

# %%
sns.barplot(data = df, x = "holiday", y="count", hue="weather")
# Out:
# <Axes: xlabel='holiday', ylabel='count'>

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Random Forest

# %% [markdown]
# # ARIMA and SARIMA
